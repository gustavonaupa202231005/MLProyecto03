# %%
import numpy as np  
import pandas as pd 
import re

from bs4 import BeautifulSoup           
from keras.preprocessing.text import Tokenizer 
from keras_preprocessing.sequence import pad_sequences
#from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords   
#from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed, Bidirectional
#from tensorflow.keras.models import Model
#from tensorflow.keras.callbacks import EarlyStopping
from keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed, Bidirectional
from keras.models import Model
from keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")

# %%
data = pd. read_csv("datasets/Reviews.csv", nrows=10000)

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",

                           "didn't": "did not", "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",

                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",

                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",

                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",

                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",

                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",

                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",

                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",

                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",

                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",

                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",

                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",

                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",

                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",

                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",

                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",

                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",

                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",

                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",

                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",

                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",

                           "you're": "you are", "you've": "you have"}

# %%
data.loc[:,"Text"][:10]
# Out:
# 0    I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labr...
# 1             Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# 2    This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with ...
# 3    If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The fl...
# 4                                                               Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.
# 5    I got a wild hair for taffy and ordered this five pound bag. The taffy was all very enjoyable with many flavors: watermelon, root beer, melon, peppermint, grape, etc. My only complaint is there wa...
# 6    This saltwater taffy had great flavors and was very soft and chewy.  Each candy was individually wrapped well.  None of the candies were stuck together, which did happen in the expensive version, ...
# 7                                                               This taffy is so good.  It is very soft and chewy.  The flavors are amazing.  I would definitely recommend you buying it.  Very satisfying!!
# 8                                                                        Right now I'm mostly just sprouting this so my cats can eat the grass. They love it. I rotate it around with Wheatgrass and Rye too
# 9                                                                  This is a very healthy dog food. Good for their digestion. Also good for small puppies. My dog eats her required amount at every feeding.
# Name: Text, dtype: object

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\GNC\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))
def text_cleaner(text):
    newString = text.lower()
    newString = BeautifulSoup(newString, "lxml").text
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"','', newString)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString) 
    tokens = [w for w in newString.split() if not w in stop_words]
    long_words=[]
    for i in tokens:
        if len(i)>=3:                  #removing short word
            long_words.append(i)   
    return (" ".join(long_words)).strip()

cleaned_text = []
for t in data['Text']:
    cleaned_text.append(text_cleaner(t))

# %%
data['Summary'][:10]
# Out:
# 0                            Good Quality Dog Food
# 1                                Not as Advertised
# 2                            "Delight" says it all
# 3                                   Cough Medicine
# 4                                      Great taffy
# 5                                       Nice Taffy
# 6    Great!  Just as good as the expensive brands!
# 7                           Wonderful, tasty taffy
# 8                                       Yay Barley
# 9                                 Healthy Dog Food
# Name: Summary, dtype: object

# %%
def summary_cleaner(text):
    newString = re.sub('"','', text)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString)
    newString = newString.lower()
    tokens=newString.split()
    newString=''
    for i in tokens:
        if len(i)>1:                                 
            newString=newString+i+' '  
    return newString

# %%
cleaned_summary = []
for t in data['Summary']:
    cleaned_summary.append(summary_cleaner(str(t)))

data['cleaned_text']=cleaned_text
data['cleaned_summary']=cleaned_summary
data['cleaned_summary'].replace('', np.nan, inplace=True)
data.dropna(axis=0,inplace=True)

# %%
data.loc[data["Summary"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, ProductId, UserId, ProfileName, HelpfulnessNumerator, HelpfulnessDenominator, Score, Time, Summary, Text, cleaned_text, cleaned_summary]
# Index: []

# %%
data['cleaned_summary'] = data['cleaned_summary'].apply(lambda x : '_START_ '+ x + ' _END_')

# %%
for i in range(5):
    print("Review:",data['cleaned_text'][i])
    print("Summary:",data['cleaned_summary'][i])
    print("\n")
# Out:
# Review: bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better
# Summary: _START_ good quality dog food  _END_
#
#
# Review: product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo
# Summary: _START_ not as advertised  _END_
#
#
# Review: confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch
# Summary: _START_ delight says it all  _END_
#
#
# Review: looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal
# Summary: _START_ cough medicine  _END_
#
#
# Review: great taffy great price wide assortment yummy taffy delivery quick taffy lover deal
# Summary: _START_ great taffy  _END_

# %%
import matplotlib.pyplot as plt
text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in data['cleaned_text']:
      text_word_count.append(len(i.split()))

for i in data['cleaned_summary']:
      summary_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})
length_df.hist(bins = 30)
plt.show()

# %%
max_len_text=80 
max_len_summary=10

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(data['cleaned_text'],data['cleaned_summary'],test_size=0.1,random_state=0,shuffle=True)

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer()
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr,  maxlen=max_len_text, padding='post') 
x_val   =   pad_sequences(x_val, maxlen=max_len_text, padding='post')

x_voc_size   =  len(x_tokenizer.word_index) +1

# %%
#preparing a tokenizer for summary on training data 
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(list(y_tr))

#convert summary sequences into integer sequences
y_tr    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr, maxlen=max_len_summary, padding='post')
y_val   =   pad_sequences(y_val, maxlen=max_len_summary, padding='post')

y_voc_size  =   len(y_tokenizer.word_index) +1

# %%
from attention import AttentionLayer

# %%
from keras import backend as K 
K.clear_session() 
latent_dim = 500 


# Encoder 
encoder_inputs = Input(shape=(max_len_text,)) 
enc_emb = Embedding(x_voc_size, latent_dim,trainable=True)(encoder_inputs) 

#LSTM 1 
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True) 
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb) 

#LSTM 2 
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True) 
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1) 

#LSTM 3 
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True) 
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2) 

# Set up the decoder. 
decoder_inputs = Input(shape=(None,)) 
dec_emb_layer = Embedding(y_voc_size, latent_dim,trainable=True) 
dec_emb = dec_emb_layer(decoder_inputs) 

#LSTM using encoder_states as initial state
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True) 
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c]) 

#Attention Layer
attn_layer = AttentionLayer(name='attention_layer') 
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs]) 

# Concat attention output and decoder LSTM output 
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#Dense layer
decoder_dense = TimeDistributed(Dense(y_voc_size, activation='softmax')) 
decoder_outputs = decoder_dense(decoder_concat_input) 

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs) 
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 80)]         0           []
#
#  embedding (Embedding)          (None, 80, 500)      8434000     ['input_1[0][0]']
#
#  lstm (LSTM)                    [(None, 80, 500),    2002000     ['embedding[0][0]']
#                                  (None, 500),
#                                  (None, 500)]
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  lstm_1 (LSTM)                  [(None, 80, 500),    2002000     ['lstm[0][0]']
#                                  (None, 500),
#                                  (None, 500)]
#
#  embedding_1 (Embedding)        (None, None, 500)    2123500     ['input_2[0][0]']
#
#  lstm_2 (LSTM)                  [(None, 80, 500),    2002000     ['lstm_1[0][0]']
#                                  (None, 500),
#                                  (None, 500)]
#
#  lstm_3 (LSTM)                  [(None, None, 500),  2002000     ['embedding_1[0][0]',
#                                  (None, 500),                     'lstm_2[0][1]',
#                                  (None, 500)]                     'lstm_2[0][2]']
#
#  attention_layer (AttentionLaye  ((None, None, 500),  500500     ['lstm_2[0][0]',
#  r)                              (None, None, 80))                'lstm_3[0][0]']
#
#  concat_layer (Concatenate)     (None, None, 1000)   0           ['lstm_3[0][0]',
#                                                                   'attention_layer[0][0]']
#
#  time_distributed (TimeDistribu  (None, None, 4247)  4251247     ['concat_layer[0][0]']
#  ted)
#
# ==================================================================================================
# Total params: 23,317,247
# Trainable params: 23,317,247
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
decoder_outputs
# Out:
# <KerasTensor: shape=(None, None, 4247) dtype=float32 (created by layer 'time_distributed')>

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)

# %%
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=50,batch_size=512, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# callbacks=[es]
# Out:
# Epoch 1/50
# 18/18 [==============================] - 189s 10s/step - loss: 3.2794 - val_loss: 2.6965
# Epoch 2/50
# 18/18 [==============================] - 176s 10s/step - loss: 2.8550 - val_loss: 2.6715
# Epoch 3/50
# 18/18 [==============================] - 189s 11s/step - loss: 2.7853 - val_loss: 2.6568
# Epoch 4/50
# 18/18 [==============================] - 179s 10s/step - loss: 2.7299 - val_loss: 2.6284
# Epoch 5/50
# 18/18 [==============================] - 176s 10s/step - loss: 2.6700 - val_loss: 2.6122
# Epoch 6/50
# 18/18 [==============================] - 173s 10s/step - loss: 2.6237 - val_loss: 2.6074
# Epoch 7/50
# 18/18 [==============================] - 173s 10s/step - loss: 2.5697 - val_loss: 2.5852
# Epoch 8/50
# 18/18 [==============================] - 172s 10s/step - loss: 2.5071 - val_loss: 2.5630
# Epoch 9/50
# 18/18 [==============================] - 173s 10s/step - loss: 2.4475 - val_loss: 2.5388
# Epoch 10/50
# 18/18 [==============================] - 172s 10s/step - loss: 2.3780 - val_loss: 2.5009
# Epoch 11/50
# 18/18 [==============================] - 168s 9s/step - loss: 2.3026 - val_loss: 2.4991
# Epoch 12/50
# 18/18 [==============================] - 162s 9s/step - loss: 2.2424 - val_loss: 2.5109
# Epoch 13/50
# 18/18 [==============================] - 160s 9s/step - loss: 2.1655 - val_loss: 2.4556
# Epoch 14/50
# 18/18 [==============================] - 157s 9s/step - loss: 2.0923 - val_loss: 2.4799
# Epoch 15/50
# 18/18 [==============================] - 157s 9s/step - loss: 2.0206 - val_loss: 2.4684
# Epoch 16/50
# 18/18 [==============================] - 157s 9s/step - loss: 1.9524 - val_loss: 2.4563
# Epoch 17/50
# 18/18 [==============================] - 157s 9s/step - loss: 1.8746 - val_loss: 2.4454
# Epoch 18/50
# 18/18 [==============================] - 159s 9s/step - loss: 1.8051 - val_loss: 2.4616
# Epoch 19/50
# 18/18 [==============================] - 170s 9s/step - loss: 1.7344 - val_loss: 2.4560
# Epoch 20/50
# 18/18 [==============================] - 163s 9s/step - loss: 1.6648 - val_loss: 2.4511
# Epoch 21/50
# 18/18 [==============================] - 160s 9s/step - loss: 1.5972 - val_loss: 2.4617
# Epoch 22/50
# 18/18 [==============================] - 156s 9s/step - loss: 1.5231 - val_loss: 2.4856
# Epoch 23/50
# 18/18 [==============================] - 161s 9s/step - loss: 1.4615 - val_loss: 2.5088
# Epoch 24/50
# 18/18 [==============================] - 160s 9s/step - loss: 1.3936 - val_loss: 2.5045
# Epoch 25/50
# 18/18 [==============================] - 160s 9s/step - loss: 1.3387 - val_loss: 2.4842
# Epoch 26/50
# 18/18 [==============================] - 159s 9s/step - loss: 1.2780 - val_loss: 2.4931
# Epoch 27/50
# 18/18 [==============================] - 159s 9s/step - loss: 1.2177 - val_loss: 2.5038
# Epoch 28/50
# 18/18 [==============================] - 159s 9s/step - loss: 1.1550 - val_loss: 2.4975
# Epoch 29/50
# 18/18 [==============================] - 159s 9s/step - loss: 1.1154 - val_loss: 2.5126
# Epoch 30/50
# 18/18 [==============================] - 160s 9s/step - loss: 1.0523 - val_loss: 2.5083
# Epoch 31/50
# 18/18 [==============================] - 159s 9s/step - loss: 1.0086 - val_loss: 2.5286
# Epoch 32/50
# 18/18 [==============================] - 159s 9s/step - loss: 0.9523 - val_loss: 2.5390
# Epoch 33/50
# 18/18 [==============================] - 160s 9s/step - loss: 0.9075 - val_loss: 2.5556
# Epoch 34/50
# 18/18 [==============================] - 159s 9s/step - loss: 0.8613 - val_loss: 2.5616
# Epoch 35/50
# 18/18 [==============================] - 156s 9s/step - loss: 0.8136 - val_loss: 2.5727
# Epoch 36/50
# 18/18 [==============================] - 156s 9s/step - loss: 0.7713 - val_loss: 2.5829
# Epoch 37/50
# 18/18 [==============================] - 156s 9s/step - loss: 0.7269 - val_loss: 2.6105
# Epoch 38/50
# 18/18 [==============================] - 156s 9s/step - loss: 0.6878 - val_loss: 2.6098
# Epoch 39/50
# 18/18 [==============================] - 151s 8s/step - loss: 0.6552 - val_loss: 2.6281
# Epoch 40/50
# 18/18 [==============================] - 156s 9s/step - loss: 0.6121 - val_loss: 2.6325
# Epoch 41/50
# 18/18 [==============================] - 155s 9s/step - loss: 0.5745 - val_loss: 2.6372
# Epoch 42/50
# 18/18 [==============================] - 156s 9s/step - loss: 0.5454 - val_loss: 2.6504
# Epoch 43/50
# 18/18 [==============================] - 156s 9s/step - loss: 0.5085 - val_loss: 2.6862
# Epoch 44/50
# 18/18 [==============================] - 151s 8s/step - loss: 0.4722 - val_loss: 2.7000
# Epoch 45/50
# 18/18 [==============================] - 151s 8s/step - loss: 0.4541 - val_loss: 2.7090
# Epoch 46/50
# 18/18 [==============================] - 159s 9s/step - loss: 0.4090 - val_loss: 2.7052
# Epoch 47/50
# 18/18 [==============================] - 156s 9s/step - loss: 0.3910 - val_loss: 2.7453
# Epoch 48/50
# 18/18 [==============================] - 156s 9s/step - loss: 0.3576 - val_loss: 2.7655
# Epoch 49/50
# 18/18 [==============================] - 157s 9s/step - loss: 0.3336 - val_loss: 2.7788
# Epoch 50/50
# 18/18 [==============================] - 153s 8s/step - loss: 0.3080 - val_loss: 2.8246

# %%
from matplotlib import pyplot 
pyplot.plot(history.history['loss'], label='train') 
pyplot.plot(history.history['val_loss'], label='test') 
pyplot.legend() 
pyplot.show()

# %%
reverse_target_word_index=y_tokenizer.index_word 
reverse_source_word_index=x_tokenizer.index_word 
target_word_index=y_tokenizer.word_index

# %%
reverse_target_word_index
# Out:
# {1: 'start',
#  2: 'end',
#  3: 'great',
#  4: 'good',
#  5: 'the',
#  6: 'not',
#  7: 'for',
#  8: 'best',
#  9: 'and',
#  10: 'coffee',
#  11: 'it',
#  12: 'my',
#  13: 'but',
#  14: 'love',
#  15: 'is',
#  16: 'of',
#  17: 'this',
#  18: 'to',
#  19: 'product',
#  20: 'taste',
#  21: 'delicious',
#  22: 'flavor',
#  23: 'very',
#  24: 'in',
#  25: 'tea',
#  26: 'excellent',
#  27: 'food',
#  28: 'yummy',
#  29: 'you',
#  30: 'tasty',
#  31: 'like',
#  32: 'dog',
#  33: 'as',
#  34: 'too',
#  35: 'price',
#  36: 'these',
#  37: 'favorite',
#  38: 'chips',
#  39: 'ever',
#  40: 'so',
#  41: 'with',
#  42: 'cup',
#  43: 'are',
#  44: 'hot',
#  45: 'just',
#  46: 'better',
#  47: 'free',
#  48: 'on',
#  49: 'have',
#  50: 'no',
#  51: 'stuff',
#  52: 'chocolate',
#  53: 'what',
#  54: 'sweet',
#  55: 'perfect',
#  56: 'loves',
#  57: 'awesome',
#  58: 'yum',
#  59: 'bad',
#  60: 'nice',
#  61: 'healthy',
#  62: 'quality',
#  63: 'me',
#  64: 'mix',
#  65: 'one',
#  66: 'than',
#  67: 'cups',
#  68: 'snack',
#  69: 'wonderful',
#  70: 'really',
#  71: 'all',
#  72: 'tasting',
#  73: 'gluten',
#  74: 'cocoa',
#  75: 'tastes',
#  76: 'at',
#  77: 'can',
#  78: 'your',
#  79: 'little',
#  80: 'be',
#  81: 'much',
#  82: 'do',
#  83: 'easy',
#  84: 'buy',
#  85: 'them',
#  86: 'organic',
#  87: 'from',
#  88: 'dogs',
#  89: 'cat',
#  90: 'ok',
#  91: 'that',
#  92: 'drink',
#  93: 'treat',
#  94: 'if',
#  95: 'cats',
#  96: 'an',
#  97: 'will',
#  98: 'fresh',
#  99: 'baby',
#  100: 'pretty',
#  101: 'sugar',
#  102: 'more',
#  103: 'treats',
#  104: 'alternative',
#  105: 'was',
#  106: 'way',
#  107: 'amazing',
#  108: 'decaf',
#  109: 'out',
#  110: 'soda',
#  111: 'they',
#  112: 'value',
#  113: 'puck',
#  114: 'up',
#  115: 'works',
#  116: 'water',
#  117: 'find',
#  118: 'popcorn',
#  119: 'wolfgang',
#  120: 'smooth',
#  121: 'sauce',
#  122: 'fantastic',
#  123: 'or',
#  124: 'real',
#  125: 'our',
#  126: 'cookies',
#  127: 'amazon',
#  128: 'hard',
#  129: 'low',
#  130: 'expensive',
#  131: 'breakfast',
#  132: 'beans',
#  133: 'milk',
#  134: 'juice',
#  135: 'strong',
#  136: 'pancakes',
#  137: 'make',
#  138: 'makes',
#  139: 'flavored',
#  140: 'pop',
#  141: 'does',
#  142: 'vanilla',
#  143: 'there',
#  144: 'gift',
#  145: 'had',
#  146: 'some',
#  147: 'natural',
#  148: 'new',
#  149: 'eat',
#  150: 'coconut',
#  151: 'again',
#  152: 'we',
#  153: 'work',
#  154: 'only',
#  155: 'use',
#  156: 'keurig',
#  157: 'happy',
#  158: 'get',
#  159: 'money',
#  160: 'green',
#  161: 'okay',
#  162: 'nothing',
#  163: 'decent',
#  164: 'small',
#  165: 'deal',
#  166: 'other',
#  167: 'right',
#  168: 'light',
#  169: 'roast',
#  170: 'by',
#  171: 'energy',
#  172: 'go',
#  173: 'would',
#  174: 'did',
#  175: 'made',
#  176: 'service',
#  177: 'gum',
#  178: 'orange',
#  179: 'salt',
#  180: 'disappointed',
#  181: 'chip',
#  182: 'far',
#  183: 'high',
#  184: 'bisquick',
#  185: 'candy',
#  186: 'rich',
#  187: 'licorice',
#  188: 'bit',
#  189: 'blend',
#  190: 'don',
#  191: 'well',
#  192: 'weak',
#  193: 'convenient',
#  194: 'expected',
#  195: 'worth',
#  196: 'poor',
#  197: 'bitter',
#  198: 'bread',
#  199: 'refreshing',
#  200: 'packaging',
#  201: 'review',
#  202: 'spicy',
#  203: 'white',
#  204: 'oil',
#  205: 'awful',
#  206: 'wow',
#  207: 'old',
#  208: 'absolutely',
#  209: 'popchips',
#  210: 'seeds',
#  211: 'fruit',
#  212: 'soup',
#  213: 'am',
#  214: 'item',
#  215: 'fun',
#  216: 'never',
#  217: 'potato',
#  218: 'time',
#  219: 'calorie',
#  220: 'hazelnut',
#  221: 'loved',
#  222: 'shipping',
#  223: 'variety',
#  224: 'could',
#  225: 'flavors',
#  226: 'dark',
#  227: 'french',
#  228: 'without',
#  229: 'baking',
#  230: 'special',
#  231: 'got',
#  232: 'first',
#  233: 'how',
#  234: 'instant',
#  235: 'mild',
#  236: 'choice',
#  237: 'enough',
#  238: 'pack',
#  239: 'kids',
#  240: 'rice',
#  241: 'worst',
#  242: 'about',
#  243: 'why',
#  244: 'quick',
#  245: 'tasted',
#  246: 'corn',
#  247: 'still',
#  248: 'super',
#  249: 'bed',
#  250: 'fast',
#  251: 'horrible',
#  252: 'gf',
#  253: 'most',
#  254: 'even',
#  255: 'has',
#  256: 'switch',
#  257: 'different',
#  258: 'day',
#  259: 'disappointing',
#  260: 'terrible',
#  261: 'kettle',
#  262: 'jerky',
#  263: 'disposakups',
#  264: 'bag',
#  265: 'crazy',
#  266: 'powder',
#  267: 'beware',
#  268: 'almost',
#  269: 'own',
#  270: 'simply',
#  271: 'substitute',
#  272: 'now',
#  273: 'found',
#  274: 'over',
#  275: 'whole',
#  276: 'order',
#  277: 'flavorful',
#  278: 'after',
#  279: 'waste',
#  280: 'medium',
#  281: 'brew',
#  282: 'diet',
#  283: 'size',
#  284: 'brand',
#  285: 'were',
#  286: 'cake',
#  287: 'something',
#  288: 'yet',
#  289: 'customer',
#  290: 'vinegar',
#  291: 'ingredients',
#  292: 'fan',
#  293: 'pancake',
#  294: 'full',
#  295: 'salty',
#  296: 'formula',
#  297: 'cereal',
#  298: 'surprisingly',
#  299: 'lots',
#  300: 'senseo',
#  301: 'pods',
#  302: 'nuts',
#  303: 'oatmeal',
#  304: 'its',
#  305: 'true',
#  306: 'soy',
#  307: 'big',
#  308: 'wrong',
#  309: 'idea',
#  310: 'want',
#  311: 'fat',
#  312: 'stale',
#  313: 'oz',
#  314: 'life',
#  315: 'those',
#  316: 'name',
#  317: 'syrup',
#  318: 'store',
#  319: 'grass',
#  320: 'cost',
#  321: 'crackers',
#  322: 'didn',
#  323: 'soft',
#  324: 'another',
#  325: 'tried',
#  326: 'yuck',
#  327: 'chicken',
#  328: 'disposable',
#  329: 'canned',
#  330: 'butter',
#  331: 'available',
#  332: 'stars',
#  333: 'less',
#  334: 'bought',
#  335: 'pricey',
#  336: 'family',
#  337: 'last',
#  338: 'snacks',
#  339: 'grove',
#  340: 'goat',
#  341: 'who',
#  342: 'try',
#  343: 'miracle',
#  344: 'regular',
#  345: 'lovers',
#  346: 'fabulous',
#  347: 'every',
#  348: 'non',
#  349: 'gravy',
#  350: 'honey',
#  351: 'back',
#  352: 'dessert',
#  353: 'say',
#  354: 'sure',
#  355: 'any',
#  356: 'nasty',
#  357: 'pleased',
#  358: 'bold',
#  359: 'smells',
#  360: 'calories',
#  361: 'square',
#  362: 'outstanding',
#  363: 'where',
#  364: 'must',
#  365: 'texture',
#  366: 'down',
#  367: 'favorites',
#  368: 'bland',
#  369: 'lot',
#  370: 'espresso',
#  371: 'beef',
#  372: 'quite',
#  373: 'goodness',
#  374: 'when',
#  375: 'caramel',
#  376: 'son',
#  377: 'carbonated',
#  378: 'unique',
#  379: 'used',
#  380: 'smell',
#  381: 'spice',
#  382: 'needs',
#  383: 'muffins',
#  384: 'iced',
#  385: 'broken',
#  386: 'think',
#  387: 'cookie',
#  388: 'ordered',
#  389: 'cans',
#  390: 'aroma',
#  391: 'heaven',
#  392: 'sticks',
#  393: 'totally',
#  394: 'products',
#  395: 'misleading',
#  396: 'delivery',
#  397: 'cannot',
#  398: 'always',
#  399: 'plant',
#  400: 'interesting',
#  401: 'picky',
#  402: 'bbq',
#  403: 'us',
#  404: 'thing',
#  405: 'crunchy',
#  406: 'batch',
#  407: 'packaged',
#  408: 'flour',
#  409: 'house',
#  410: 'tangy',
#  411: 'english',
#  412: 'same',
#  413: 'mini',
#  414: 'likes',
#  415: 'bite',
#  416: 'reviews',
#  417: 'here',
#  418: 'cracker',
#  419: 'aftertaste',
#  420: 'mustard',
#  421: 'overpriced',
#  422: 'healthier',
#  423: 'should',
#  424: 'crunch',
#  425: 'off',
#  426: 'red',
#  427: 'beautiful',
#  428: 'bags',
#  429: 'cheap',
#  430: 'disappointment',
#  431: 'bars',
#  432: 'addictive',
#  433: 'fine',
#  434: 'tangerine',
#  435: 'wish',
#  436: 'dressing',
#  437: 'earth',
#  438: 'lover',
#  439: 'clam',
#  440: 'mmm',
#  441: 'thought',
#  442: 'peanut',
#  443: 'close',
#  444: 'delish',
#  445: 'open',
#  446: 'ground',
#  447: 'received',
#  448: 'health',
#  449: 'cherry',
#  450: 'home',
#  451: 'please',
#  452: 'beverage',
#  453: 'cheese',
#  454: 'oh',
#  455: 'bar',
#  456: 'many',
#  457: 'cute',
#  458: 'need',
#  459: 'summer',
#  460: 'priced',
#  461: 'cheaper',
#  462: 'waffle',
#  463: 'extra',
#  464: 'newman',
#  465: 'highly',
#  466: 'recommended',
#  467: 'finally',
#  468: 'know',
#  469: 'world',
#  470: 'watery',
#  471: 'black',
#  472: 'wild',
#  473: 'waffles',
#  474: 'delight',
#  475: 'artificial',
#  476: 'option',
#  477: 'meal',
#  478: 'olive',
#  479: 'two',
#  480: 'top',
#  481: 'lovely',
#  482: 'loose',
#  483: 'chia',
#  484: 'buying',
#  485: 'kitty',
#  486: 'china',
#  487: 'brown',
#  488: 'maybe',
#  489: 'crispy',
#  490: 'helps',
#  491: 'average',
#  492: 'jamaica',
#  493: 'em',
#  494: 'impressed',
#  495: 'their',
#  496: 'bean',
#  497: 'hit',
#  498: 'eating',
#  499: 'sodium',
#  500: 'weight',
#  501: 'contains',
#  502: 'around',
#  503: 'dont',
#  504: 'thai',
#  505: 'protein',
#  506: 'nutrition',
#  507: 'into',
#  508: 'though',
#  509: 'raw',
#  510: 'premium',
#  511: 'pasta',
#  512: 'purchase',
#  513: 'arrived',
#  514: 'box',
#  515: 'inexpensive',
#  516: 'looking',
#  517: 'salsa',
#  518: 'greatest',
#  519: 'gave',
#  520: 'leaf',
#  521: 'smaller',
#  522: 'long',
#  523: 'cool',
#  524: 'anywhere',
#  525: 'add',
#  526: 'satisfying',
#  527: 'agree',
#  528: 'liked',
#  529: 'onion',
#  530: 'dry',
#  531: 'solution',
#  532: 'cold',
#  533: 'aluminum',
#  534: 'awsome',
#  535: 'year',
#  536: 'stevia',
#  537: 'thin',
#  538: 'crisps',
#  539: 'been',
#  540: 'kcup',
#  541: 'worked',
#  542: 'miss',
#  543: 'everything',
#  544: 'foods',
#  545: 'star',
#  546: 'grow',
#  547: 'baked',
#  548: 'tofu',
#  549: 'tart',
#  550: 're',
#  551: 'chowder',
#  552: 'dairy',
#  553: 'others',
#  554: 'plain',
#  555: 'jars',
#  556: 'look',
#  557: 'berry',
#  558: 'cooking',
#  559: 'stores',
#  560: 'original',
#  561: 'rock',
#  562: 'meh',
#  563: 'dinner',
#  564: 'morning',
#  565: 'simple',
#  566: 'seasoning',
#  567: 'days',
#  568: 'beer',
#  569: 'away',
#  570: 'extract',
#  571: 'getting',
#  572: 'gourmet',
#  573: 'ounce',
#  574: 'experience',
#  575: 'care',
#  576: 'surprise',
#  577: 'problems',
#  578: 'wanted',
#  579: 'advertised',
#  580: 'yes',
#  581: 'date',
#  582: 'crisp',
#  583: 'omg',
#  584: 'saver',
#  585: 'acidic',
#  586: 'wine',
#  587: 'country',
#  588: 'caribou',
#  589: 'instead',
#  590: 'extremely',
#  591: 'everyone',
#  592: 'chili',
#  593: 'actually',
#  594: 'serve',
#  595: 'making',
#  596: 'sweetener',
#  597: 'brewers',
#  598: 'keeps',
#  599: 'daughter',
#  600: 'mouth',
#  601: 'mill',
#  602: 'salad',
#  603: 'addicted',
#  604: 'thick',
#  605: 'tortilla',
#  606: 'toddler',
#  607: 'slightly',
#  608: 'then',
#  609: 'grain',
#  610: 'clean',
#  611: 'yuk',
#  612: 'liquor',
#  613: 'lemon',
#  614: 'bpa',
#  615: 'effective',
#  616: 'mint',
#  617: 'columbian',
#  618: 'lightly',
#  619: 'allergy',
#  620: 'homemade',
#  621: 'eh',
#  622: 'sorry',
#  623: 'ice',
#  624: 'yuban',
#  625: 'people',
#  626: 'pepper',
#  627: 'coco',
#  628: 'garlic',
#  629: 'touch',
#  630: 'came',
#  631: 'enjoyable',
#  632: 'filters',
#  633: 'creamy',
#  634: 'sooo',
#  635: 'coffees',
#  636: 'ginger',
#  637: 'oreo',
#  638: 'company',
#  639: 'enjoy',
#  640: 'ones',
#  641: 'feel',
#  642: 'thanks',
#  643: 'fruity',
#  644: 'key',
#  645: 'lamb',
#  646: 'surprised',
#  647: 'unremarkable',
#  648: 'glad',
#  649: 'happened',
#  650: 'allergies',
#  651: 'training',
#  652: 'shipped',
#  653: 'chocolates',
#  654: 'msg',
#  655: 'scrumptious',
#  656: 'jelly',
#  657: 'give',
#  658: 'looks',
#  659: 'sunflower',
#  660: 'edible',
#  661: 'read',
#  662: 'leaves',
#  663: 'boxes',
#  664: 'sinus',
#  665: 'tasteless',
#  666: 'friend',
#  667: 'man',
#  668: 'earl',
#  669: 'grey',
#  670: 'help',
#  671: 'difference',
#  672: 'things',
#  673: 'problem',
#  674: 'fave',
#  675: 'market',
#  676: 'rocks',
#  677: 'warning',
#  678: 'rodeo',
#  679: 'drive',
#  680: 'damaged',
#  681: 'banana',
#  682: 'wheat',
#  683: 'plastic',
#  684: 'dr',
#  685: 'pineapple',
#  686: 'mixed',
#  687: 'goes',
#  688: 'belly',
#  689: 'handy',
#  690: 'pound',
#  691: 'base',
#  692: 'italian',
#  693: 'darn',
#  694: 'beat',
#  695: 'vegan',
#  696: 'issues',
#  697: 'nd',
#  698: 'sour',
#  699: 'prefer',
#  700: 'version',
#  701: 'windows',
#  702: 'mushy',
#  703: 'exactly',
#  704: 'may',
#  705: 'pick',
#  706: 'hate',
#  707: 'teeth',
#  708: 'second',
#  709: 'definitely',
#  710: 'amazingly',
#  711: 'gets',
#  712: 'pieces',
#  713: 'almond',
#  714: 'sick',
#  715: 'stash',
#  716: 'picture',
#  717: 'believe',
#  718: 'defective',
#  719: 'fragrant',
#  720: 'cuppa',
#  721: 'except',
#  722: 'terrific',
#  723: 'custard',
#  724: 'mrs',
#  725: 'packs',
#  726: 'mediocre',
#  727: 'easily',
#  728: 'lacks',
#  729: 'tree',
#  730: 'superb',
#  731: 'replacement',
#  732: 'amish',
#  733: 'kona',
#  734: 'com',
#  735: 'mahogany',
#  736: 'amount',
#  737: 'machine',
#  738: 'pops',
#  739: 'sardines',
#  740: 'fans',
#  741: 'local',
#  742: 'bubble',
#  743: 'disgusting',
#  744: 'change',
#  745: 'control',
#  746: 'anytime',
#  747: 'recipe',
#  748: 'disapointed',
#  749: 'panda',
#  750: 'sucralose',
#  751: 'daily',
#  752: 'brands',
#  753: 'carb',
#  754: 'authentic',
#  755: 'grandpa',
#  756: 'po',
#  757: 'basket',
#  758: 'lunch',
#  759: 'heat',
#  760: 'runny',
#  761: 'either',
#  762: 'party',
#  763: 'delivered',
#  764: 'boost',
#  765: 'twice',
#  766: 'false',
#  767: 'sensitive',
#  768: 'hawaiian',
#  769: 'else',
#  770: 'described',
#  771: 'winner',
#  772: 'pleasing',
#  773: 'nut',
#  774: 'versatile',
#  775: 'winter',
#  776: 'ate',
#  777: 'changed',
#  778: 'balance',
#  779: 'added',
#  780: 'huge',
#  781: 'odd',
#  782: 'curry',
#  783: 'tummy',
#  784: 'mmmmm',
#  785: 'dirty',
#  786: 'using',
#  787: 'messy',
#  788: 'line',
#  789: 'watch',
#  790: 'lime',
#  791: 'ingredient',
#  792: 'heavenly',
#  793: 'hint',
#  794: 'keep',
#  795: 'bacon',
#  796: 'kind',
#  797: 'sweetner',
#  798: 'creme',
#  799: 'sea',
#  800: 'longer',
#  801: 'diets',
#  802: 'rating',
#  803: 'cafe',
#  804: 'kit',
#  805: 'saves',
#  806: 'guilt',
#  807: 'creamer',
#  808: 'ghirardelli',
#  809: 'choc',
#  810: 'especially',
#  811: 'stock',
#  812: 'gone',
#  813: 'before',
#  814: 'mostly',
#  815: 'least',
#  816: 'stephen',
#  817: 'vita',
#  818: 'funny',
#  819: 'skittles',
#  820: 'bother',
#  821: 'seems',
#  822: 'ugh',
#  823: 'mountain',
#  824: 'busy',
#  825: 'side',
#  826: 'barely',
#  827: 'once',
#  828: 'careful',
#  829: 'stick',
#  830: 'rip',
#  831: 'safe',
#  832: 'strength',
#  833: 'nutritious',
#  834: 'moldy',
#  835: 'lids',
#  836: 'pizza',
#  837: 'packed',
#  838: 'teas',
#  839: 'live',
#  840: 'egg',
#  841: 'liver',
#  842: 'absolute',
#  843: 'come',
#  844: 'sweetness',
#  845: 'apple',
#  846: 'strange',
#  847: 'wasa',
#  848: 'fav',
#  849: 'news',
#  850: 'online',
#  851: 'bitterness',
#  852: 'caution',
#  853: 'paris',
#  854: 'forever',
#  855: 'dried',
#  856: 'stopped',
#  857: 'limited',
#  858: 'paws',
#  859: 'vitamin',
#  860: 'single',
#  861: 'doesn',
#  862: 'fluffy',
#  863: 'organics',
#  864: 'both',
#  865: 'said',
#  866: 'cook',
#  867: 'puppy',
#  868: 'take',
#  869: 'save',
#  870: 'pure',
#  871: 'mueslix',
#  872: 'babies',
#  873: 'biscuits',
#  874: 'chews',
#  875: 'fondant',
#  876: 'herbal',
#  877: 'nearly',
#  878: 'christmas',
#  879: 'lol',
#  880: 'cream',
#  881: 'potatoes',
#  882: 'month',
#  883: 'tell',
#  884: 'weird',
#  885: 'decaff',
#  886: 'indeed',
#  887: 'delightful',
#  888: 'pumpkin',
#  889: 'bubbly',
#  890: 'solid',
#  891: 'affordable',
#  892: 'belgian',
#  893: 'nature',
#  894: 'rule',
#  895: 'stomach',
#  896: 'yummo',
#  897: 'pricy',
#  898: 'office',
#  899: 'gross',
#  900: 'paste',
#  901: 'pearl',
#  902: 'classic',
#  903: 'condiment',
#  904: 'mixes',
#  905: 'body',
#  906: 'chew',
#  907: 'colombian',
#  908: 'snacking',
#  909: 'blood',
#  910: 'cinnamon',
#  911: 'dishes',
#  912: 'wife',
#  913: 'pod',
#  914: 'nom',
#  915: 'usa',
#  916: 'says',
#  917: 'thumbs',
#  918: 'large',
#  919: 'husband',
#  920: 'recommend',
#  921: 'kitchen',
#  922: 'standard',
#  923: 'oily',
#  924: 'put',
#  925: 'taffy',
#  926: 'holiday',
#  927: 'wake',
#  928: 'powdered',
#  929: 'lives',
#  930: 'going',
#  931: 'hodgson',
#  932: 'pay',
#  933: 'peppered',
#  934: 'filled',
#  935: 'smoked',
#  936: 'dream',
#  937: 'altoids',
#  938: 'skin',
#  939: 'ole',
#  940: 'twizzlers',
#  941: 'planet',
#  942: 'pleasant',
#  943: 'toddlers',
#  944: 'mic',
#  945: 'expired',
#  946: 'bottle',
#  947: 'issue',
#  948: 'fructose',
#  949: 'usual',
#  950: 'sodas',
#  951: 'kick',
#  952: 'actual',
#  953: 'mmmmmm',
#  954: 'island',
#  955: 'newmans',
#  956: 'adult',
#  957: 'medicine',
#  958: 'bone',
#  959: 'digestive',
#  960: 'locally',
#  961: 'gas',
#  962: 'inside',
#  963: 'design',
#  964: 'mm',
#  965: 'berries',
#  966: 'tiny',
#  967: 'plus',
#  968: 'mellow',
#  969: 'maker',
#  970: 'jack',
#  971: 'harbor',
#  972: 'clams',
#  973: 'gotta',
#  974: 'allergic',
#  975: 'bird',
#  976: 'brownie',
#  977: 'muffin',
#  978: 'de',
#  979: 'hands',
#  980: 'rather',
#  981: 'lollipops',
#  982: 'tender',
#  983: 'slices',
#  984: 'hydrogenated',
#  985: 'gold',
#  986: 'dissapointed',
#  987: 'acid',
#  988: 'extreme',
#  989: 'perfection',
#  990: 'wolfgand',
#  991: 'dented',
#  992: 'bigger',
#  993: 'farms',
#  994: 'working',
#  995: 'highest',
#  996: 'tablets',
#  997: 'seed',
#  998: 'reasonably',
#  999: 'pocky',
#  1000: 'ol',
#  ...}

# %%
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# decoder inference
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_len_text,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs)

# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat)

# Final decoder model
decoder_model = Model(
[decoder_inputs] + [decoder_hidden_state_input, decoder_state_input_h, decoder_state_input_c],
[decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))

    # Chose the 'start' word as the first word of the target sequence
    target_seq[0, 0] = target_word_index['start']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]

        if(sampled_token!='end'):
            decoded_sentence += ' '+sampled_token

            # Exit condition: either hit max length or find stop word.
            if (sampled_token == 'end' or len(decoded_sentence.split()) >= (max_len_summary-1)):
                stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
      if((i!=0 and i!=target_word_index['start']) and i!=target_word_index['end']):  # end
        newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
      if(i!=0):
        newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
len(x_val)
# Out:
# 1000

# %%
len(y_val)
# Out:
# 1000

# %%
for i in range(len(x_val)):
  print("Review:",seq2text(x_val[i]))
  print("Original summary:",seq2summary(y_val[i]))
  print("Predicted summary:",decode_sequence(x_val[i].reshape(1,max_len_text)))
  print("\n")
# Out:
# Review: good flavor coconut flavor subtle overpowering comparison another coconut coffee green mountain coconut flavor overdone opinion
# Original summary: good coffee
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11692\3549211724.py in <module>
#       2   print("Review:",seq2text(x_val[i]))
#       3   print("Original summary:",seq2summary(y_val[i]))
# ----> 4   print("Predicted summary:",decode_sequence(x_val[i].reshape(1,max_len_text)))
#       5   print("\n")
#
# ~\AppData\Local\Temp\ipykernel_11692\3108854982.py in decode_sequence(input_seq)
#      16         # Sample a token
#      17         sampled_token_index = np.argmax(output_tokens[0, -1, :])
# ---> 18         sampled_token = reverse_target_word_index[sampled_token_index]
#      19
#      20         if(sampled_token!='end'):
#
# KeyError: 0
